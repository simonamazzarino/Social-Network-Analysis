# %% [markdown]
# # Data Preparation

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import warnings
import powerlaw
import matplotlib.colors as mcolors
import ast
import time

warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ## Import .csv files + (very) basic EDA and data preparation
# In this section we:
# * read the four csv files (one per semester)
# * concat all the five csv into a single one
# * drop useless features

# %%
df_primo = pd.read_csv("../data_collection/data_biden/primo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_secondo = pd.read_csv("../data_collection/data_biden/secondo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_terzo = pd.read_csv("../data_collection/data_biden/terzo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_quarto = pd.read_csv("../data_collection/data_biden/quarto_semestre.csv", na_filter=True, na_values='[]', lineterminator='\n')
df_quinto = pd.read_csv("../data_collection/data_biden/quinto_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')

# %%
df_primo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144711 entries, 0 to 144710
# Data columns (total 37 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       144711 non-null  int64
#  1   id               144711 non-null  int64
#  2   conversation_id  144711 non-null  int64
#  3   created_at       144711 non-null  object
#  4   date             144711 non-null  object
#  5   time             144711 non-null  object
#  6   timezone         144711 non-null  int64
#  7   user_id          144711 non-null  int64
#  8   username         144711 non-null  object
#  9   name             144705 non-null  object
#  10  place            128 non-null     object
#  11  tweet            144711 non-null  object
#  12  language         144711 non-null  object
#  13  mentions         31200 non-null   object
#  14  urls             38819 non-null   object
#  15  photos           21480 non-null   object
#  16  replies_count    144711 non-null  int64
#  17  retweets_count   144711 non-null  int64
#  18  likes_count      144711 non-null  int64
#  19  hashtags         144638 non-null  object
#  20  cashtags         108 non-null     object
#  21  link             144711 non-null  object
#  22  retweet          144711 non-null  bool
#  23  quote_url        29499 non-null   object
#  24  video            144711 non-null  int64
#  25  thumbnail        23908 non-null   object
#  26  near             0 non-null       float64
#  27  geo              0 non-null       float64
#  28  source           0 non-null       float64
#  29  user_rt_id       0 non-null       float64
#  30  user_rt          0 non-null       float64
#  31  retweet_id       0 non-null       float64
#  32  reply_to         45071 non-null   object
#  33  retweet_date     0 non-null       float64
#  34  translate        0 non-null       float64
#  35  trans_src        0 non-null       float64
#  36  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(10), int64(9), object(17)
# memory usage: 39.9+ MB

# %%
df_secondo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147576 entries, 0 to 147575
# Data columns (total 37 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       147576 non-null  int64
#  1   id               147576 non-null  int64
#  2   conversation_id  147576 non-null  int64
#  3   created_at       147576 non-null  object
#  4   date             147576 non-null  object
#  5   time             147576 non-null  object
#  6   timezone         147576 non-null  int64
#  7   user_id          147576 non-null  int64
#  8   username         147576 non-null  object
#  9   name             147564 non-null  object
#  10  place            150 non-null     object
#  11  tweet            147576 non-null  object
#  12  language         147576 non-null  object
#  13  mentions         28416 non-null   object
#  14  urls             43072 non-null   object
#  15  photos           23848 non-null   object
#  16  replies_count    147576 non-null  int64
#  17  retweets_count   147576 non-null  int64
#  18  likes_count      147576 non-null  int64
#  19  hashtags         147531 non-null  object
#  20  cashtags         356 non-null     object
#  21  link             147576 non-null  object
#  22  retweet          147576 non-null  bool
#  23  quote_url        27957 non-null   object
#  24  video            147576 non-null  int64
#  25  thumbnail        27716 non-null   object
#  26  near             0 non-null       float64
#  27  geo              0 non-null       float64
#  28  source           0 non-null       float64
#  29  user_rt_id       0 non-null       float64
#  30  user_rt          0 non-null       float64
#  31  retweet_id       0 non-null       float64
#  32  reply_to         43510 non-null   object
#  33  retweet_date     0 non-null       float64
#  34  translate        0 non-null       float64
#  35  trans_src        0 non-null       float64
#  36  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(10), int64(9), object(17)
# memory usage: 40.7+ MB

# %%
df_terzo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125386 entries, 0 to 125385
# Data columns (total 37 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       125386 non-null  int64
#  1   id               125386 non-null  int64
#  2   conversation_id  125386 non-null  int64
#  3   created_at       125386 non-null  object
#  4   date             125386 non-null  object
#  5   time             125386 non-null  object
#  6   timezone         125386 non-null  int64
#  7   user_id          125386 non-null  int64
#  8   username         125386 non-null  object
#  9   name             125134 non-null  object
#  10  place            128 non-null     object
#  11  tweet            125386 non-null  object
#  12  language         125386 non-null  object
#  13  mentions         25808 non-null   object
#  14  urls             50035 non-null   object
#  15  photos           24690 non-null   object
#  16  replies_count    125386 non-null  int64
#  17  retweets_count   125386 non-null  int64
#  18  likes_count      125386 non-null  int64
#  19  hashtags         125091 non-null  object
#  20  cashtags         684 non-null     object
#  21  link             125386 non-null  object
#  22  retweet          125386 non-null  bool
#  23  quote_url        19942 non-null   object
#  24  video            125386 non-null  int64
#  25  thumbnail        28386 non-null   object
#  26  near             0 non-null       float64
#  27  geo              0 non-null       float64
#  28  source           0 non-null       float64
#  29  user_rt_id       0 non-null       float64
#  30  user_rt          0 non-null       float64
#  31  retweet_id       0 non-null       float64
#  32  reply_to         17952 non-null   object
#  33  retweet_date     0 non-null       float64
#  34  translate        0 non-null       float64
#  35  trans_src        0 non-null       float64
#  36  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(10), int64(9), object(17)
# memory usage: 34.6+ MB

# %%
df_quarto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132830 entries, 0 to 132829
# Data columns (total 37 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       132830 non-null  int64
#  1   id               132830 non-null  int64
#  2   conversation_id  132830 non-null  int64
#  3   created_at       132830 non-null  object
#  4   date             132830 non-null  object
#  5   time             132830 non-null  object
#  6   timezone         132830 non-null  int64
#  7   user_id          132830 non-null  int64
#  8   username         132830 non-null  object
#  9   name             132541 non-null  object
#  10  place            86 non-null      object
#  11  tweet            132830 non-null  object
#  12  language         132830 non-null  object
#  13  mentions         25237 non-null   object
#  14  urls             46863 non-null   object
#  15  photos           21605 non-null   object
#  16  replies_count    132830 non-null  int64
#  17  retweets_count   132830 non-null  int64
#  18  likes_count      132830 non-null  int64
#  19  hashtags         132495 non-null  object
#  20  cashtags         555 non-null     object
#  21  link             132830 non-null  object
#  22  retweet          132830 non-null  bool
#  23  quote_url        24164 non-null   object
#  24  video            132830 non-null  int64
#  25  thumbnail        25795 non-null   object
#  26  near             0 non-null       float64
#  27  geo              0 non-null       float64
#  28  source           0 non-null       float64
#  29  user_rt_id       0 non-null       float64
#  30  user_rt          0 non-null       float64
#  31  retweet_id       0 non-null       float64
#  32  reply_to         15918 non-null   object
#  33  retweet_date     0 non-null       float64
#  34  translate        0 non-null       float64
#  35  trans_src        0 non-null       float64
#  36  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(10), int64(9), object(17)
# memory usage: 36.6+ MB

# %%
df_quinto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123991 entries, 0 to 123990
# Data columns (total 37 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       123991 non-null  int64
#  1   id               123991 non-null  int64
#  2   conversation_id  123991 non-null  int64
#  3   created_at       123991 non-null  object
#  4   date             123991 non-null  object
#  5   time             123991 non-null  object
#  6   timezone         123991 non-null  int64
#  7   user_id          123991 non-null  int64
#  8   username         123991 non-null  object
#  9   name             123929 non-null  object
#  10  place            42 non-null      object
#  11  tweet            123991 non-null  object
#  12  language         123991 non-null  object
#  13  mentions         22315 non-null   object
#  14  urls             39464 non-null   object
#  15  photos           20054 non-null   object
#  16  replies_count    123991 non-null  int64
#  17  retweets_count   123991 non-null  int64
#  18  likes_count      123991 non-null  int64
#  19  hashtags         123903 non-null  object
#  20  cashtags         902 non-null     object
#  21  link             123991 non-null  object
#  22  retweet          123991 non-null  bool
#  23  quote_url        23663 non-null   object
#  24  video            123991 non-null  int64
#  25  thumbnail        24957 non-null   object
#  26  near             0 non-null       float64
#  27  geo              0 non-null       float64
#  28  source           0 non-null       float64
#  29  user_rt_id       0 non-null       float64
#  30  user_rt          0 non-null       float64
#  31  retweet_id       0 non-null       float64
#  32  reply_to         17160 non-null   object
#  33  retweet_date     0 non-null       float64
#  34  translate        0 non-null       float64
#  35  trans_src        0 non-null       float64
#  36  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(10), int64(9), object(17)
# memory usage: 34.2+ MB

# %%
joinDF = [df_primo, df_secondo, df_terzo, df_quarto, df_quinto]

# %%
df = pd.concat(joinDF)

# %%
df
# Out:
#         Unnamed: 0                   id      conversation_id  \
# 0                0  1218684471211245568  1218684471211245568
# 1                1  1218684453494632449  1218663554250727424
# 2                4  1218683884994473984  1218678939947864064
# 3                5  1218683765674987525  1218683765674987520
# 4                6  1218683747417120768  1218683747417120768
# ...            ...                  ...                  ...
# 123986        1007  1479472860208844802  1479472860208844800
# 123987        1008  1479472457828478976  1479472457828478976
# 123988        1009  1479472401763258374  1479439038423597056
# 123989        1010  1479472233307328517  1479472233307328512
# 123990        1013  1479471875084660737  1479471875084660736
#
#                        created_at        date      time  timezone  \
# 0       2020-01-18 23:59:54+00:00  2020-01-18  23:59:54       100
# 1       2020-01-18 23:59:50+00:00  2020-01-18  23:59:50       100
# 2       2020-01-18 23:57:34+00:00  2020-01-18  23:57:34       100
# 3       2020-01-18 23:57:06+00:00  2020-01-18  23:57:06       100
# 4       2020-01-18 23:57:02+00:00  2020-01-18  23:57:02       100
# ...                           ...         ...       ...       ...
# 123986  2022-01-07 15:19:51+00:00  2022-01-07  15:19:51       100
# 123987  2022-01-07 15:18:15+00:00  2022-01-07  15:18:15       100
# 123988  2022-01-07 15:18:02+00:00  2022-01-07  15:18:02       100
# 123989  2022-01-07 15:17:22+00:00  2022-01-07  15:17:22       100
# 123990  2022-01-07 15:15:56+00:00  2022-01-07  15:15:56       100
#
#                     user_id         username  \
# 0                  90497917       davidschor
# 1                 175711368          trayntp
# 2                 967521853  badphotography_
# 3       1199496918029742083      glendowek42
# 4                 543761210   mimitexasangel
# ...                     ...              ...
# 123986           1062465110    johngililland
# 123987   942241440855343104           ps9714
# 123988           1267982563         howserob
# 123989  1414321685835177985    sheilachicago
# 123990  1209118401198575621    reiwakunichan
#
#                                         name  ... geo source user_rt_id  \
# 0           David Schor (Biden=#BlueTrump) 💚  ... NaN    NaN        NaN
# 1           Biden is the More Effective Evil  ... NaN    NaN        NaN
# 2                                      Robby  ... NaN    NaN        NaN
# 3                         Camigo Lordotic⚙️🐛  ... NaN    NaN        NaN
# 4       Cannabis food is our Healthcare🍃🌿🌱🌳🍏  ... NaN    NaN        NaN
# ...                                      ...  ...  ..    ...        ...
# 123986                        John Gililland  ... NaN    NaN        NaN
# 123987         The Great War & Modern Memory  ... NaN    NaN        NaN
# 123988                             Rob Howse  ... NaN    NaN        NaN
# 123989                                Sheila  ... NaN    NaN        NaN
# 123990                        令和クニちゃん💎 @MJGA  ... NaN    NaN        NaN
#
#        user_rt retweet_id                                           reply_to  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN  [{'screen_name': 'number1fan_2', 'name': 'Davi...
# 2          NaN        NaN  [{'screen_name': 'WoobieTuesday', 'name': 'Woo...
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# ...        ...        ...                                                ...
# 123986     NaN        NaN                                                NaN
# 123987     NaN        NaN                                                NaN
# 123988     NaN        NaN  [{'screen_name': 'lettywho1', 'name': 'Dr Nazr...
# 123989     NaN        NaN                                                NaN
# 123990     NaN        NaN                                                NaN
#
#         retweet_date  translate  trans_src trans_dest
# 0                NaN        NaN        NaN        NaN
# 1                NaN        NaN        NaN        NaN
# 2                NaN        NaN        NaN        NaN
# 3                NaN        NaN        NaN        NaN
# 4                NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...
# 123986           NaN        NaN        NaN        NaN
# 123987           NaN        NaN        NaN        NaN
# 123988           NaN        NaN        NaN        NaN
# 123989           NaN        NaN        NaN        NaN
# 123990           NaN        NaN        NaN        NaN
#
# [674494 rows x 37 columns]

# %%
del df["Unnamed: 0"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674494 entries, 0 to 123990
# Data columns (total 36 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               674494 non-null  int64
#  1   conversation_id  674494 non-null  int64
#  2   created_at       674494 non-null  object
#  3   date             674494 non-null  object
#  4   time             674494 non-null  object
#  5   timezone         674494 non-null  int64
#  6   user_id          674494 non-null  int64
#  7   username         674494 non-null  object
#  8   name             673873 non-null  object
#  9   place            534 non-null     object
#  10  tweet            674494 non-null  object
#  11  language         674494 non-null  object
#  12  mentions         132976 non-null  object
#  13  urls             218253 non-null  object
#  14  photos           111677 non-null  object
#  15  replies_count    674494 non-null  int64
#  16  retweets_count   674494 non-null  int64
#  17  likes_count      674494 non-null  int64
#  18  hashtags         673658 non-null  object
#  19  cashtags         2605 non-null    object
#  20  link             674494 non-null  object
#  21  retweet          674494 non-null  bool
#  22  quote_url        125225 non-null  object
#  23  video            674494 non-null  int64
#  24  thumbnail        130762 non-null  object
#  25  near             0 non-null       float64
#  26  geo              0 non-null       float64
#  27  source           0 non-null       float64
#  28  user_rt_id       0 non-null       float64
#  29  user_rt          0 non-null       float64
#  30  retweet_id       0 non-null       float64
#  31  reply_to         139611 non-null  object
#  32  retweet_date     0 non-null       float64
#  33  translate        0 non-null       float64
#  34  trans_src        0 non-null       float64
#  35  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(10), int64(8), object(17)
# memory usage: 185.9+ MB

# %%
len(df["user_id"].unique())
# Out:
# 162636

# %%
len(df["conversation_id"].value_counts(normalize=True))
# Out:
# 636485

# %%
df_definitivo = df.drop(["retweet_date", "translate", "trans_src", "trans_dest", "near", "geo", "source", "user_rt_id","user_rt", "retweet_id", "place", "thumbnail", "video", "language", "photos" , "created_at", "timezone", "cashtags", "urls", "retweet", "quote_url"], axis=1)

# %%
df_definitivo.reset_index(inplace=True)

# %%
df_definitivo
# Out:
#          index                   id      conversation_id        date  \
# 0            0  1218684471211245568  1218684471211245568  2020-01-18
# 1            1  1218684453494632449  1218663554250727424  2020-01-18
# 2            2  1218683884994473984  1218678939947864064  2020-01-18
# 3            3  1218683765674987525  1218683765674987520  2020-01-18
# 4            4  1218683747417120768  1218683747417120768  2020-01-18
# ...        ...                  ...                  ...         ...
# 674489  123986  1479472860208844802  1479472860208844800  2022-01-07
# 674490  123987  1479472457828478976  1479472457828478976  2022-01-07
# 674491  123988  1479472401763258374  1479439038423597056  2022-01-07
# 674492  123989  1479472233307328517  1479472233307328512  2022-01-07
# 674493  123990  1479471875084660737  1479471875084660736  2022-01-07
#
#             time              user_id         username  \
# 0       23:59:54             90497917       davidschor
# 1       23:59:50            175711368          trayntp
# 2       23:57:34            967521853  badphotography_
# 3       23:57:06  1199496918029742083      glendowek42
# 4       23:57:02            543761210   mimitexasangel
# ...          ...                  ...              ...
# 674489  15:19:51           1062465110    johngililland
# 674490  15:18:15   942241440855343104           ps9714
# 674491  15:18:02           1267982563         howserob
# 674492  15:17:22  1414321685835177985    sheilachicago
# 674493  15:15:56  1209118401198575621    reiwakunichan
#
#                                         name  \
# 0           David Schor (Biden=#BlueTrump) 💚
# 1           Biden is the More Effective Evil
# 2                                      Robby
# 3                         Camigo Lordotic⚙️🐛
# 4       Cannabis food is our Healthcare🍃🌿🌱🌳🍏
# ...                                      ...
# 674489                        John Gililland
# 674490         The Great War & Modern Memory
# 674491                             Rob Howse
# 674492                                Sheila
# 674493                        令和クニちゃん💎 @MJGA
#
#                                                     tweet  \
# 0       #JoeBiden accusing the Sanders campaign of dis...
# 1       @number1fan_2 @BMarchetich There are 2 other v...
# 2       @WoobieTuesday @HeatherGautney @JoeBiden @Bern...
# 3       Democrats: "#Trump is mentally unfit for being...
# 4       @DNC needs to reign in #JoeBiden ~ He can not ...
# ...                                                   ...
# 674489  This looks like an SNL set.   My how the resol...
# 674490  Did you miss President Biden's stunning speech...
# 674491  @lettywho1 @POTUS @WhiteHouse @StateDept As yo...
# 674492  People who critique #Biden perplex me. Like, w...
# 674493  ［BREAKING］#BreakingNews President Biden's impa...
#
#                                                  mentions  replies_count  \
# 0                                                     NaN              0
# 1                                                     NaN              0
# 2                                                     NaN              0
# 3                                                     NaN              0
# 4                                                     NaN              0
# ...                                                   ...            ...
# 674489                                                NaN              0
# 674490                                                NaN              0
# 674491  [{'screen_name': 'rutiteitel', 'name': 'ruti t...              0
# 674492                                                NaN              0
# 674493  [{'screen_name': 'potus', 'name': 'president b...              0
#
#         retweets_count  likes_count  \
# 0                    1            2
# 1                    1            0
# 2                    8           14
# 3                    0            0
# 4                    0            0
# ...                ...          ...
# 674489               0            0
# 674490               4           11
# 674491               1            0
# 674492               0            0
# 674493               0            0
#
#                                                  hashtags  \
# 0       ['joebiden', 'berniebreathesfire', 'thetruthbe...
# 1                                            ['joebiden']
# 2                 ['joebiden', 'bidensocialsecuritycuts']
# 3       ['trump', 'joebiden', 'hilarious', 'hypocrisy'...
# 4       ['joebiden', 'lie', 'democratic', 'voters', 'v...
# ...                                                   ...
# 674489                           ['joebiden', 'shameful']
# 674490                             ['biden', 'democracy']
# 674491                                          ['biden']
# 674492                                          ['biden']
# 674493  ['breakingnews', 'joebiden', 'xijinping', 'the...
#
#                                                      link  \
# 0       https://twitter.com/davidschor/status/12186844...
# 1       https://twitter.com/trayNTP/status/12186844534...
# 2       https://twitter.com/BadPhotography_/status/121...
# 3       https://twitter.com/GlenDowek42/status/1218683...
# 4       https://twitter.com/MimiTexasAngel/status/1218...
# ...                                                   ...
# 674489  https://twitter.com/JohnGililland/status/14794...
# 674490  https://twitter.com/ps9714/status/147947245782...
# 674491  https://twitter.com/howserob/status/1479472401...
# 674492  https://twitter.com/SheilaChicago/status/14794...
# 674493  https://twitter.com/ReiwaKuniChan/status/14794...
#
#                                                  reply_to
# 0                                                     NaN
# 1       [{'screen_name': 'number1fan_2', 'name': 'Davi...
# 2       [{'screen_name': 'WoobieTuesday', 'name': 'Woo...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 674489                                                NaN
# 674490                                                NaN
# 674491  [{'screen_name': 'lettywho1', 'name': 'Dr Nazr...
# 674492                                                NaN
# 674493                                                NaN
#
# [674494 rows x 16 columns]

# %%
del df_definitivo["index"]

# %%
df_definitivo = df_definitivo.dropna()

# %%
(df_definitivo["date"] <= "2020-05-25").value_counts()
# Out:
# False    14294
# True      5364
# Name: date, dtype: int64

# %%
df_definitivo["retweets_count"].describe()
# Out:
# count   19658
# mean        1
# std        10
# min         0
# 25%         0
# 50%         0
# 75%         0
# max       733
# Name: retweets_count, dtype: float64

# %%
len(df_definitivo["user_id"].unique())
# Out:
# 8581

# %%
df_definitivo["reply_to"]
# Out:
# 13        [{'screen_name': 'peterschweizer', 'name': 'Pe...
# 21        [{'screen_name': 'notonboard', 'name': 'Maury ...
# 25        [{'screen_name': 'JoyceWhiteVance', 'name': 'J...
# 26        [{'screen_name': 'MonaSalama_', 'name': 'Mona ...
# 36        [{'screen_name': 'hollyotterbein', 'name': 'Ho...
#                                 ...
# 673914    [{'screen_name': 'CharlieCrist', 'name': 'Char...
# 673975    [{'screen_name': 'POTUS', 'name': 'President B...
# 674101    [{'screen_name': 'TomKattman', 'name': 'Tom Ka...
# 674200    [{'screen_name': 'MarketRebels', 'name': 'Mark...
# 674491    [{'screen_name': 'lettywho1', 'name': 'Dr Nazr...
# Name: reply_to, Length: 19658, dtype: object

# %%
df_definitivo.reset_index(inplace=True)

# %%
del df_definitivo["index"]

# %%
df_definitivo
# Out:
#                         id      conversation_id        date      time  \
# 0      1218680146376429574  1218643531058884608  2020-01-18  23:42:43
# 1      1218677328395538432  1218652137988730880  2020-01-18  23:31:31
# 2      1218675784912703488  1218252588371652608  2020-01-18  23:25:23
# 3      1218675672844914688  1218673452690935808  2020-01-18  23:24:56
# 4      1218674539934244864  1218665950532317184  2020-01-18  23:20:26
# ...                    ...                  ...         ...       ...
# 19653  1479552880310833153  1479524598991491072  2022-01-07  20:37:50
# 19654  1479539892648652800  1479256472630579200  2022-01-07  19:46:13
# 19655  1479521180730146828  1479516741696995328  2022-01-07  18:31:52
# 19656  1479506373952032772  1479494789980561408  2022-01-07  17:33:02
# 19657  1479472401763258374  1479439038423597056  2022-01-07  15:18:02
#
#                    user_id         username                              name  \
# 0       738486583725305857           pamnsc                      🇺🇸 Pamnsc 🇮🇱
# 1                175711368          trayntp  Biden is the More Effective Evil
# 2      1184244724301008898       klima_jean                 Christopher Tyler
# 3               3418384394      edenfieldpl                   CommunityCorner
# 4                  7334712           ctman1             Stephen BERNIE Herron
# ...                    ...              ...                               ...
# 19653  1365444820357967874    thekennykarma      💎 ✋ $inging Ape - Ξξ variant
# 19654           2825786045     runeaglesrun                              Rick
# 19655            531563448       katerina5k             🍊Katerina5k🍊MAGAGang🍊
# 19656             75077990  chattahoocheejb                      Jeff Barrett
# 19657           1267982563         howserob                         Rob Howse
#
#                                                    tweet  \
# 0      @peterschweizer Hey @scdp  @WhipClyburn @harri...
# 1      @notonboard @GunnelsWarren @GetRealWBernie Not...
# 2      @JoyceWhiteVance #Politico 1st laid out that #...
# 3      @MonaSalama_ Looks like #Biden must be 1st Wit...
# 4      @hollyotterbein Remember, the media hasn’t bee...
# ...                                                  ...
# 19653  @CharlieCrist @GovRonDeSantis So like a typica...
# 19654  @POTUS Coming from the person who authorized t...
# 19655  @TomKattman I may have stolen "Polident #Biden...
# 19656  @MarketRebels I know @MarketRebels only fancie...
# 19657  @lettywho1 @POTUS @WhiteHouse @StateDept As yo...
#
#                                                 mentions  replies_count  \
# 0      [{'screen_name': 'scdp', 'name': 'south caroli...              0
# 1      [{'screen_name': 'politifact', 'name': 'politi...              2
# 2      [{'screen_name': 'democrats', 'name': 'democra...              0
# 3      [{'screen_name': 'whitehouse', 'name': 'the wh...              0
# 4      [{'screen_name': 'hollyotterbein', 'name': 'ho...              0
# ...                                                  ...            ...
# 19653  [{'screen_name': 'potus', 'name': 'president b...              1
# 19654  [{'screen_name': 'whcos', 'name': 'ronald klai...              0
# 19655  [{'screen_name': 'greggutfeld', 'name': 'gregg...              1
# 19656  [{'screen_name': 'marketrebels', 'name': 'mark...              0
# 19657  [{'screen_name': 'rutiteitel', 'name': 'ruti t...              0
#
#        retweets_count  likes_count  \
# 0                   1            0
# 1                   0            1
# 2                   0            0
# 3                   0            0
# 4                   0            1
# ...               ...          ...
# 19653               0            4
# 19654               0            0
# 19655               0            1
# 19656               0            0
# 19657               1            0
#
#                                                 hashtags  \
# 0                                ['biden', 'charleston']
# 1                                           ['joebiden']
# 2      ['politico', 'ukraine', 'trump', 'giuliani', '...
# 3        ['biden', 'china', 'iran', 'russia', 'ukraine']
# 4                                ['biden', 'bernie2020']
# ...                                                  ...
# 19653                                          ['biden']
# 19654                           ['biden', 'bidenspeech']
# 19655                                          ['biden']
# 19656                                       ['joebiden']
# 19657                                          ['biden']
#
#                                                     link  \
# 0      https://twitter.com/pamnsc/status/121868014637...
# 1      https://twitter.com/trayNTP/status/12186773283...
# 2      https://twitter.com/klima_jean/status/12186757...
# 3      https://twitter.com/EdenfieldPl/status/1218675...
# 4      https://twitter.com/CtMan1/status/121867453993...
# ...                                                  ...
# 19653  https://twitter.com/thekennykarma/status/14795...
# 19654  https://twitter.com/runeaglesrun/status/147953...
# 19655  https://twitter.com/katerina5k/status/14795211...
# 19656  https://twitter.com/ChattahoocheeJB/status/147...
# 19657  https://twitter.com/howserob/status/1479472401...
#
#                                                 reply_to
# 0      [{'screen_name': 'peterschweizer', 'name': 'Pe...
# 1      [{'screen_name': 'notonboard', 'name': 'Maury ...
# 2      [{'screen_name': 'JoyceWhiteVance', 'name': 'J...
# 3      [{'screen_name': 'MonaSalama_', 'name': 'Mona ...
# 4      [{'screen_name': 'hollyotterbein', 'name': 'Ho...
# ...                                                  ...
# 19653  [{'screen_name': 'CharlieCrist', 'name': 'Char...
# 19654  [{'screen_name': 'POTUS', 'name': 'President B...
# 19655  [{'screen_name': 'TomKattman', 'name': 'Tom Ka...
# 19656  [{'screen_name': 'MarketRebels', 'name': 'Mark...
# 19657  [{'screen_name': 'lettywho1', 'name': 'Dr Nazr...
#
# [19658 rows x 15 columns]

# %% [markdown]
# ## Network Preprocessing
# * we preprocess the data in order to extract the relationships between users using the _reply_to_ feature
# * then we create the edgelist and we assign to each interaction, a weight

# %%
df_definitivo['reply_to'] = df_definitivo['reply_to'].map(eval)

# %%
tupla = []

# %%
for index in range(0, len(df_definitivo)):
    for dizionario in df_definitivo['reply_to'][index]:
 #     print("Mittente ",df_definitivo['user_id'][index], "id ", dizionario['id'])
      tupla.append((df_definitivo['username'][index], df_definitivo["user_id"][index], dizionario['screen_name'], dizionario["id"]))
        


        
        
df_def = pd.DataFrame(tupla, columns = ["source", "id_source","target", "id_target"])

# %%
df_def
# Out:
#                 source            id_source           target  \
# 0               pamnsc   738486583725305857   peterschweizer
# 1              trayntp            175711368       notonboard
# 2              trayntp            175711368    GunnelsWarren
# 3              trayntp            175711368   GetRealWBernie
# 4           klima_jean  1184244724301008898  JoyceWhiteVance
# ...                ...                  ...              ...
# 38329  chattahoocheejb             75077990     MarketRebels
# 38330         howserob           1267982563        lettywho1
# 38331         howserob           1267982563            POTUS
# 38332         howserob           1267982563       WhiteHouse
# 38333         howserob           1267982563        StateDept
#
#                  id_target
# 0                 62876780
# 1                 69141933
# 2               2725669979
# 3      1187166484226891776
# 4                548384458
# ...                    ...
# 38329   817007725666242561
# 38330           1654442893
# 38331  1349149096909668363
# 38332  1323730225067339784
# 38333              9624742
#
# [38334 rows x 4 columns]

# %%
df_def.to_csv("../data_collection/data/df_per_grafo.csv")

# %%
df_def = pd.read_csv("../data_collection/data/df_per_grafo.csv")

# %%
df_def
# Out:
#                 source            id_source           target  \
# 0               pamnsc   738486583725305857   peterschweizer
# 1              trayntp            175711368       notonboard
# 2              trayntp            175711368    GunnelsWarren
# 3              trayntp            175711368   GetRealWBernie
# 4           klima_jean  1184244724301008898  JoyceWhiteVance
# ...                ...                  ...              ...
# 38329  chattahoocheejb             75077990     MarketRebels
# 38330         howserob           1267982563        lettywho1
# 38331         howserob           1267982563            POTUS
# 38332         howserob           1267982563       WhiteHouse
# 38333         howserob           1267982563        StateDept
#
#                  id_target
# 0                 62876780
# 1                 69141933
# 2               2725669979
# 3      1187166484226891776
# 4                548384458
# ...                    ...
# 38329   817007725666242561
# 38330           1654442893
# 38331  1349149096909668363
# 38332  1323730225067339784
# 38333              9624742
#
# [38334 rows x 4 columns]

# %%
del df_def["Unnamed: 0"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-c645514255e1> in <module>
# ----> 1 del df_def["Unnamed: 0"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3961             # there was no match, this call should raise the appropriate
#    3962             # exception:
# -> 3963             loc = self.axes[-1].get_loc(key)
#    3964             self._mgr = self._mgr.idelete(loc)
#    3965
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Unnamed: 0'

# %%
df_def_weighted = df_def.value_counts().to_frame("weights").reset_index() 
#il peso è dato da quante volte un nodo ha risposto a un altro nodo

# %%
df_def_weighted
# Out:
#                 source            id_source          target  \
# 0      scienceinvestme            135970150        JoeBiden
# 1            elnurrik3  1172766864268832769           POTUS
# 2             dmaga101  1267802238874877953        JoeBiden
# 3          slothsforme           3842652433           POTUS
# 4           natashaejs  1262462710568022017  ProjectLincoln
# ...                ...                  ...             ...
# 32434      goldbaron08           2661167788        CHIZMAGA
# 32435      goldbaron08           2661167788     1JohnEBravo
# 32436   goinglikesixty            126478904  kaitlancollins
# 32437   goinglikesixty            126478904      carolstam7
# 32438        zungumuza           3083023038           IPBES
#
#                  id_target  weights
# 0                   939091       60
# 1      1349149096909668363       40
# 2                   939091       40
# 3      1349149096909668363       30
# 4      1205226529455632385       28
# ...                    ...      ...
# 32434             34756550        1
# 32435   973674483151237121        1
# 32436            180107694        1
# 32437            326098537        1
# 32438            140137815        1
#
# [32439 rows x 5 columns]

# %% [markdown]
# * normalize the weight value

# %%
df_def_weighted["weights"] = (df_def_weighted["weights"] - (df_def_weighted["weights"]).min())/((df_def_weighted["weights"].max()-(df_def_weighted["weights"]).min() ))

# %%
df_def_weighted.to_csv("../data_collection/data_biden/df_per_grafo_pesato.csv")

# %% [markdown]
# ## Data preprocessing for DCD
#
# * we also prepared a dataset containing the quarter information

# %%
df_primo = pd.read_csv("../data_collection/data_biden/primo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_secondo = pd.read_csv("../data_collection/data_biden/secondo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_terzo = pd.read_csv("../data_collection/data_biden/terzo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_quarto = pd.read_csv("../data_collection/data_biden/quarto_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_quinto = pd.read_csv("../data_collection/data_biden/quinto_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')

# %%
del df_primo["Unnamed: 0"]
del df_secondo["Unnamed: 0"]
del df_terzo["Unnamed: 0"]
del df_quarto["Unnamed: 0"]
del df_quinto["Unnamed: 0"]

# %%
df_definitivo_1 = df_primo.drop(["retweet_date", "translate", "trans_src", "trans_dest", "near", "geo", "source", "user_rt_id","user_rt", "retweet_id", "place", "thumbnail", "video", "language", "photos" , "created_at", "timezone", "cashtags", "urls", "retweet", "quote_url"], axis=1)
df_definitivo_2 = df_secondo.drop(["retweet_date", "translate", "trans_src", "trans_dest", "near", "geo", "source", "user_rt_id","user_rt", "retweet_id", "place", "thumbnail", "video", "language", "photos" , "created_at", "timezone", "cashtags", "urls", "retweet", "quote_url"], axis=1)
df_definitivo_3 = df_terzo.drop(["retweet_date", "translate", "trans_src", "trans_dest", "near", "geo", "source", "user_rt_id","user_rt", "retweet_id", "place", "thumbnail", "video", "language", "photos" , "created_at", "timezone", "cashtags", "urls", "retweet", "quote_url"], axis=1)
df_definitivo_4 = df_quarto.drop(["retweet_date", "translate", "trans_src", "trans_dest", "near", "geo", "source", "user_rt_id","user_rt", "retweet_id", "place", "thumbnail", "video", "language", "photos" , "created_at", "timezone", "cashtags", "urls", "retweet", "quote_url"], axis=1)
df_definitivo_5 = df_quinto.drop(["retweet_date", "translate", "trans_src", "trans_dest", "near", "geo", "source", "user_rt_id","user_rt", "retweet_id", "place", "thumbnail", "video", "language", "photos" , "created_at", "timezone", "cashtags", "urls", "retweet", "quote_url"], axis=1)

# %%
df_definitivo_1.reset_index(inplace=True)
df_definitivo_2.reset_index(inplace=True)
df_definitivo_3.reset_index(inplace=True)
df_definitivo_4.reset_index(inplace=True)
df_definitivo_5.reset_index(inplace=True)

# %%
del df_definitivo_1["index"]
del df_definitivo_2["index"]
del df_definitivo_3["index"]
del df_definitivo_4["index"]
del df_definitivo_5["index"]

# %%
df_definitivo_1 = df_definitivo_1.dropna()
df_definitivo_2 = df_definitivo_2.dropna()
df_definitivo_3 = df_definitivo_3.dropna()
df_definitivo_4 = df_definitivo_4.dropna()
df_definitivo_5 = df_definitivo_5.dropna()

# %%
df_definitivo_1['reply_to'] = df_definitivo_1['reply_to'].map(eval)
df_definitivo_2['reply_to'] = df_definitivo_2['reply_to'].map(eval)
df_definitivo_3['reply_to'] = df_definitivo_3['reply_to'].map(eval)
df_definitivo_4['reply_to'] = df_definitivo_4['reply_to'].map(eval)
df_definitivo_5['reply_to'] = df_definitivo_5['reply_to'].map(eval)

# %%
df_definitivo_1.reset_index(inplace=True)
df_definitivo_2.reset_index(inplace=True)
df_definitivo_3.reset_index(inplace=True)
df_definitivo_4.reset_index(inplace=True)
df_definitivo_5.reset_index(inplace=True)

# %%
del df_definitivo_1["index"]
del df_definitivo_2["index"]
del df_definitivo_3["index"]
del df_definitivo_4["index"]
del df_definitivo_5["index"]

# %%
df_definitivo_1
# Out:
#                        id      conversation_id        date      time  \
# 0     1218680146376429574  1218643531058884608  2020-01-18  23:42:43
# 1     1218677328395538432  1218652137988730880  2020-01-18  23:31:31
# 2     1218675784912703488  1218252588371652608  2020-01-18  23:25:23
# 3     1218675672844914688  1218673452690935808  2020-01-18  23:24:56
# 4     1218674539934244864  1218665950532317184  2020-01-18  23:20:26
# ...                   ...                  ...         ...       ...
# 6705  1264266633008361480  1263953059882905600  2020-05-23  19:47:08
# 6706  1264266065523154946  1263997603693203456  2020-05-23  19:44:53
# 6707  1264265259361153025  1264208610671943680  2020-05-23  19:41:41
# 6708  1264264614516326402  1264256420951871488  2020-05-23  19:39:07
# 6709  1264263305687969792  1264247266254061568  2020-05-23  19:33:55
#
#                   user_id       username                              name  \
# 0      738486583725305857         pamnsc                      🇺🇸 Pamnsc 🇮🇱
# 1               175711368        trayntp  Biden is the More Effective Evil
# 2     1184244724301008898     klima_jean                 Christopher Tyler
# 3              3418384394    edenfieldpl                   CommunityCorner
# 4                 7334712         ctman1             Stephen BERNIE Herron
# ...                   ...            ...                               ...
# 6705           2156028248  _not_relevant                      Greg Carlsen
# 6706   901935932122824705   daletanner18           1-65 trump'sCourtRecord
# 6707  1257055044341555201     legs781724                           legs412
# 6708   824378302693576704      1956again                      Roxy Schwarz
# 6709  1256638210039521281    live2tell_x          🔥🔥🌈Poetic_Justice_🏳️‍🌈🔥🔥
#
#                                                   tweet  \
# 0     @peterschweizer Hey @scdp  @WhipClyburn @harri...
# 1     @notonboard @GunnelsWarren @GetRealWBernie Not...
# 2     @JoyceWhiteVance #Politico 1st laid out that #...
# 3     @MonaSalama_ Looks like #Biden must be 1st Wit...
# 4     @hollyotterbein Remember, the media hasn’t bee...
# ...                                                 ...
# 6705  @davidnmartin @RexChapman That might be the BE...
# 6706  @BrunoAmato_1 Biden should be more deliberate ...
# 6707  @CJ4ShortPlz @PamEllaCasual @jeffsessions @jda...
# 6708  @SadieTNResist Don't worry @realDonaldTrump . ...
# 6709  @cenkuygur When you vote #Biden into office, y...
#
#                                                mentions  replies_count  \
# 0     [{'screen_name': 'scdp', 'name': 'south caroli...              0
# 1     [{'screen_name': 'politifact', 'name': 'politi...              2
# 2     [{'screen_name': 'democrats', 'name': 'democra...              0
# 3     [{'screen_name': 'whitehouse', 'name': 'the wh...              0
# 4     [{'screen_name': 'hollyotterbein', 'name': 'ho...              0
# ...                                                 ...            ...
# 6705  [{'screen_name': 'realdonaldtrump', 'name': 'd...              0
# 6706  [{'screen_name': 'joebiden', 'name': 'joe bide...              0
# 6707  [{'screen_name': 'joebiden', 'name': 'joe bide...              1
# 6708  [{'screen_name': 'realdonaldtrump', 'name': 'd...              0
# 6709  [{'screen_name': 'aoc', 'name': 'alexandria oc...              0
#
#       retweets_count  likes_count  \
# 0                  1            0
# 1                  0            1
# 2                  0            0
# 3                  0            0
# 4                  0            1
# ...              ...          ...
# 6705               0            0
# 6706               0            0
# 6707               0            0
# 6708               1            2
# 6709               1            0
#
#                                                hashtags  \
# 0                               ['biden', 'charleston']
# 1                                          ['joebiden']
# 2     ['politico', 'ukraine', 'trump', 'giuliani', '...
# 3       ['biden', 'china', 'iran', 'russia', 'ukraine']
# 4                               ['biden', 'bernie2020']
# ...                                                 ...
# 6705                                          ['biden']
# 6706                                       ['joebiden']
# 6707                        ['dementiajoe', 'joebiden']
# 6708  ['bluewave2020', 'votebluetosaveamerica', 'blu...
# 6709                                          ['biden']
#
#                                                    link  \
# 0     https://twitter.com/pamnsc/status/121868014637...
# 1     https://twitter.com/trayNTP/status/12186773283...
# 2     https://twitter.com/klima_jean/status/12186757...
# 3     https://twitter.com/EdenfieldPl/status/1218675...
# 4     https://twitter.com/CtMan1/status/121867453993...
# ...                                                 ...
# 6705  https://twitter.com/_Not_Relevant/status/12642...
# 6706  https://twitter.com/DaleTanner18/status/126426...
# 6707  https://twitter.com/legs781724/status/12642652...
# 6708  https://twitter.com/1956again/status/126426461...
# 6709  https://twitter.com/live2tell_x/status/1264263...
#
#                                                reply_to
# 0     [{'screen_name': 'peterschweizer', 'name': 'Pe...
# 1     [{'screen_name': 'notonboard', 'name': 'Maury ...
# 2     [{'screen_name': 'JoyceWhiteVance', 'name': 'J...
# 3     [{'screen_name': 'MonaSalama_', 'name': 'Mona ...
# 4     [{'screen_name': 'hollyotterbein', 'name': 'Ho...
# ...                                                 ...
# 6705  [{'screen_name': 'davidnmartin', 'name': 'Davi...
# 6706  [{'screen_name': 'BrunoAmato_1', 'name': 'Brun...
# 6707  [{'screen_name': 'PamEllaCasual', 'name': 'Pam...
# 6708  [{'screen_name': 'SadieTNResist', 'name': '👠💋 ...
# 6709  [{'screen_name': 'cenkuygur', 'name': 'Cenk Uy...
#
# [6710 rows x 15 columns]

# %%
lista1 = []
lista2 = []
lista3 = []
lista4 = []
lista5 = []

# %%
for index in range(0, len(df_definitivo_1)):
    for dizionario in df_definitivo_1['reply_to'][index]:
        lista1.append((df_definitivo_1['username'][index], df_definitivo_1["user_id"][index], dizionario['screen_name'], dizionario["id"], 1))
        

        
df_primoSemestre = pd.DataFrame(lista1, columns = ["username_mittente", "id_mittente","username_ricevente", "id_ricevente", "semestre"])

# %%
for index in range(0, len(df_definitivo_2)):
    for dizionario in df_definitivo_2['reply_to'][index]:
        lista2.append((df_definitivo_2['username'][index], df_definitivo_2["user_id"][index], dizionario['screen_name'], dizionario["id"], 2))
        


df_secondoSemestre = pd.DataFrame(lista2, columns = ["username_mittente", "id_mittente","username_ricevente", "id_ricevente", "semestre"])

for index in range(0, len(df_definitivo_3)):
    for dizionario in df_definitivo_3['reply_to'][index]:
        lista3.append((df_definitivo_3['username'][index], df_definitivo_3["user_id"][index], dizionario['screen_name'], dizionario["id"], 3))
        

df_terzoSemestre = pd.DataFrame(lista3, columns = ["username_mittente", "id_mittente","username_ricevente", "id_ricevente", "semestre"])

for index in range(0, len(df_definitivo_4)):
    for dizionario in df_definitivo_4['reply_to'][index]:
        lista4.append((df_definitivo_4['username'][index], df_definitivo_4["user_id"][index], dizionario['screen_name'], dizionario["id"], 4))
        
df_quartoSemestre = pd.DataFrame(lista4, columns = ["username_mittente", "id_mittente","username_ricevente", "id_ricevente", "semestre"])


for index in range(0, len(df_definitivo_5)):
    for dizionario in df_definitivo_5['reply_to'][index]:
        lista5.append((df_definitivo_5['username'][index], df_definitivo_5["user_id"][index], dizionario['screen_name'], dizionario["id"], 5))
        
df_quintoSemestre = pd.DataFrame(lista5, columns = ["username_mittente", "id_mittente","username_ricevente", "id_ricevente", "semestre"])

# %%
df_primoSemestre_w = df_primoSemestre.value_counts().to_frame("weights").reset_index()
df_secondoSemestre_w = df_secondoSemestre.value_counts().to_frame("weights").reset_index()
df_terzoSemestre_w = df_terzoSemestre.value_counts().to_frame("weights").reset_index()
df_quartoSemestre_w = df_quartoSemestre.value_counts().to_frame("weights").reset_index()
df_quintoSemestre_w = df_quintoSemestre.value_counts().to_frame("weights").reset_index()

# %%
df_primoSemestre_w["weights"] = (df_primoSemestre_w["weights"] - (df_primoSemestre_w["weights"]).min())/((df_primoSemestre_w["weights"].max()-(df_primoSemestre_w["weights"]).min() ))
df_secondoSemestre_w["weights"] = (df_secondoSemestre_w["weights"] - (df_secondoSemestre_w["weights"]).min())/((df_secondoSemestre_w["weights"].max()-(df_secondoSemestre_w["weights"]).min() ))
df_terzoSemestre_w["weights"] = (df_terzoSemestre_w["weights"] - (df_terzoSemestre_w["weights"]).min())/((df_terzoSemestre_w["weights"].max()-(df_terzoSemestre_w["weights"]).min() ))
df_quartoSemestre_w["weights"] = (df_quartoSemestre_w["weights"] - (df_quartoSemestre_w["weights"]).min())/((df_quartoSemestre_w["weights"].max()-(df_quartoSemestre_w["weights"]).min() ))
df_quintoSemestre_w["weights"] = (df_quintoSemestre_w["weights"] - (df_quintoSemestre_w["weights"]).min())/((df_quintoSemestre_w["weights"].max()-(df_quintoSemestre_w["weights"]).min() ))

# %%
df_primoSemestre_w.to_csv("../data_collection/data_biden/df_primoSemestre.csv")
df_secondoSemestre_w.to_csv("../data_collection/data_biden/df_secondoSemestre.csv")
df_terzoSemestre_w.to_csv("../data_collection/data_biden/df_terzoSemestre.csv")
df_quartoSemestre_w.to_csv("../data_collection/data_biden/df_quartoSemestre.csv")
df_quintoSemestre_w.to_csv("../data_collection/data_biden/df_quintoSemestre.csv")
