# %% [markdown]
# # Tweet temporal analysis

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 9.0 MB/s eta 0:00:0000:0100:01m
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.9.0 tenacity-8.0.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_low_memory=False
import ipywidgets as widgets

# %%
colorPicker = widgets.ColorPicker(
concise = False,
description= 'Colore',
value ='black',
disabled = False,)
colorPicker
# Out:
# ColorPicker(value='black', description='Colore')

# %%
df_primo = pd.read_csv("../data_collection/data_biden/primo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_secondo = pd.read_csv("../data_collection/data_biden/secondo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_terzo = pd.read_csv("../data_collection/data_biden/terzo_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
df_quarto = pd.read_csv("../data_collection/data_biden/quarto_semestre.csv", na_filter=True, na_values='[]', lineterminator='\n')
df_quinto = pd.read_csv("../data_collection/data_biden/quinto_semestre.csv", na_filter=True, na_values='[]',lineterminator='\n')
# Out:
# /Users/simonamazzarino/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (10,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/simonamazzarino/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
joinDF = [df_primo, df_secondo, df_terzo, df_quarto, df_quinto]
df = pd.concat(joinDF)

# %%
del df["Unnamed: 0"]

# %%
df
# Out:
#                          id      conversation_id                 created_at  \
# 0       1218684471211245568  1218684471211245568  2020-01-18 23:59:54+00:00
# 1       1218684453494632449  1218663554250727424  2020-01-18 23:59:50+00:00
# 2       1218683884994473984  1218678939947864064  2020-01-18 23:57:34+00:00
# 3       1218683765674987525  1218683765674987520  2020-01-18 23:57:06+00:00
# 4       1218683747417120768  1218683747417120768  2020-01-18 23:57:02+00:00
# ...                     ...                  ...                        ...
# 123986  1479472860208844802  1479472860208844800  2022-01-07 15:19:51+00:00
# 123987  1479472457828478976  1479472457828478976  2022-01-07 15:18:15+00:00
# 123988  1479472401763258374  1479439038423597056  2022-01-07 15:18:02+00:00
# 123989  1479472233307328517  1479472233307328512  2022-01-07 15:17:22+00:00
# 123990  1479471875084660737  1479471875084660736  2022-01-07 15:15:56+00:00
#
#               date      time  timezone              user_id         username  \
# 0       2020-01-18  23:59:54       100             90497917       davidschor
# 1       2020-01-18  23:59:50       100            175711368          trayntp
# 2       2020-01-18  23:57:34       100            967521853  badphotography_
# 3       2020-01-18  23:57:06       100  1199496918029742083      glendowek42
# 4       2020-01-18  23:57:02       100            543761210   mimitexasangel
# ...            ...       ...       ...                  ...              ...
# 123986  2022-01-07  15:19:51       100           1062465110    johngililland
# 123987  2022-01-07  15:18:15       100   942241440855343104           ps9714
# 123988  2022-01-07  15:18:02       100           1267982563         howserob
# 123989  2022-01-07  15:17:22       100  1414321685835177985    sheilachicago
# 123990  2022-01-07  15:15:56       100  1209118401198575621    reiwakunichan
#
#                                         name place  ... geo source user_rt_id  \
# 0           David Schor (Biden=#BlueTrump) 💚   NaN  ... NaN    NaN        NaN
# 1           Biden is the More Effective Evil   NaN  ... NaN    NaN        NaN
# 2                                      Robby   NaN  ... NaN    NaN        NaN
# 3                         Camigo Lordotic⚙️🐛   NaN  ... NaN    NaN        NaN
# 4       Cannabis food is our Healthcare🍃🌿🌱🌳🍏   NaN  ... NaN    NaN        NaN
# ...                                      ...   ...  ...  ..    ...        ...
# 123986                        John Gililland   NaN  ... NaN    NaN        NaN
# 123987         The Great War & Modern Memory   NaN  ... NaN    NaN        NaN
# 123988                             Rob Howse   NaN  ... NaN    NaN        NaN
# 123989                                Sheila   NaN  ... NaN    NaN        NaN
# 123990                        令和クニちゃん💎 @MJGA   NaN  ... NaN    NaN        NaN
#
#        user_rt retweet_id                                           reply_to  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN  [{'screen_name': 'number1fan_2', 'name': 'Davi...
# 2          NaN        NaN  [{'screen_name': 'WoobieTuesday', 'name': 'Woo...
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# ...        ...        ...                                                ...
# 123986     NaN        NaN                                                NaN
# 123987     NaN        NaN                                                NaN
# 123988     NaN        NaN  [{'screen_name': 'lettywho1', 'name': 'Dr Nazr...
# 123989     NaN        NaN                                                NaN
# 123990     NaN        NaN                                                NaN
#
#         retweet_date  translate trans_src trans_dest
# 0                NaN        NaN       NaN        NaN
# 1                NaN        NaN       NaN        NaN
# 2                NaN        NaN       NaN        NaN
# 3                NaN        NaN       NaN        NaN
# 4                NaN        NaN       NaN        NaN
# ...              ...        ...       ...        ...
# 123986           NaN        NaN       NaN        NaN
# 123987           NaN        NaN       NaN        NaN
# 123988           NaN        NaN       NaN        NaN
# 123989           NaN        NaN       NaN        NaN
# 123990           NaN        NaN       NaN        NaN
#
# [674494 rows x 36 columns]

# %%
by_month = pd.to_datetime(df['date']).dt.to_period('M').value_counts().sort_index()
by_month.index = pd.PeriodIndex(by_month.index)
df_month = by_month.rename_axis('month').reset_index(name='tweets')
df_month
# Out:
#       month  tweets
# 0   2020-01   17932
# 1   2020-02   21706
# 2   2020-03   27277
# 3   2020-04   26176
# 4   2020-05   26916
# 5   2020-06   24529
# 6   2020-07   26492
# 7   2020-08   25516
# 8   2020-09   24172
# 9   2020-10   25959
# 10  2020-11   21700
# 11  2020-12   23912
# 12  2021-01   21828
# 13  2021-02   20434
# 14  2021-03   22285
# 15  2021-04   20568
# 16  2021-05   20828
# 17  2021-06   19372
# 18  2021-07   22170
# 19  2021-08   22429
# 20  2021-09   23429
# 21  2021-10   19503
# 22  2021-11   21142
# 23  2021-12   24228
# 24  2022-01   24827
# 25  2022-02   18664
# 26  2022-03   21146
# 27  2022-04   20764
# 28  2022-05   21555
# 29  2022-06   17035

# %%
#plt.rcParams["figure.figsize"]=[12,8]
sns.set_style("darkgrid")
colors=['#15259d']
df_month.plot(x='month', y = 'tweets', color = colors)
plt.title("Number of tweets per month")
plt.xlabel("Months")
plt.ylabel("Tweets")
#plt.xticks(df_month.index,df_month['month'], rotation = 45)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.despine(right = True)
g= sns.barplot(x='month', y='tweets', data = df_month)
g.set_xticklabels(g.get_xticklabels(), rotation = 45)
g.set_title('Number of tweets per month')
# Out:
# Text(0.5, 1.0, 'Number of tweets per month')
